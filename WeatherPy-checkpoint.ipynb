# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Impor the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 610

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# Set the API base URL
url = "https://api.openweathermap.org/data/2.5/weather?"
units = "metric"
base_url = f"{url}appid={weather_api_key}&units={units}&q="

# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url = f"{base_url}{city}"
    
    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = requests.get(city_url).json()

        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_date = city_weather["dt"]

        # Append the City information into city_data list
        city_data.append({"City": city, 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
              
# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | itoman
# Processing Record 2 of Set 1 | fereydun kenar
# Processing Record 3 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 4 of Set 1 | bengkulu
# Processing Record 5 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 6 of Set 1 | umzimvubu
# City not found. Skipping...
# Processing Record 7 of Set 1 | albany
# Processing Record 8 of Set 1 | katsuura
# Processing Record 9 of Set 1 | ilhabela
# Processing Record 10 of Set 1 | hobart
# Processing Record 11 of Set 1 | flinders
# Processing Record 12 of Set 1 | fairbanks
# Processing Record 13 of Set 1 | springbok
# Processing Record 14 of Set 1 | saint-chamond
# Processing Record 15 of Set 1 | port lincoln
# Processing Record 16 of Set 1 | husavik
# Processing Record 17 of Set 1 | butaritari
# Processing Record 18 of Set 1 | bani walid
# Processing Record 19 of Set 1 | ribeira grande
# Processing Record 20 of Set 1 | progreso
# Processing Record 21 of Set 1 | jamestown
# Processing Record 22 of Set 1 | saint george
# Processing Record 23 of Set 1 | ushuaia
# Processing Record 24 of Set 1 | sur
# Processing Record 25 of Set 1 | kodiak
# Processing Record 26 of Set 1 | tasiilaq
# Processing Record 27 of Set 1 | mundra
# Processing Record 28 of Set 1 | faya
# Processing Record 29 of Set 1 | mataura
# Processing Record 30 of Set 1 | poso
# Processing Record 31 of Set 1 | ancud
# Processing Record 32 of Set 1 | sumbawa
# City not found. Skipping...
# Processing Record 33 of Set 1 | yankton
# Processing Record 34 of Set 1 | puerto ayora
# Processing Record 35 of Set 1 | chuy
# Processing Record 36 of Set 1 | new norfolk
# Processing Record 37 of Set 1 | nemuro
# Processing Record 38 of Set 1 | sault sainte marie
# Processing Record 39 of Set 1 | anadyr
# Processing Record 40 of Set 1 | nazca
# Processing Record 41 of Set 1 | hermanus
# Processing Record 42 of Set 1 | quepos
# Processing Record 43 of Set 1 | avera
# Processing Record 44 of Set 1 | esperance
# Processing Record 45 of Set 1 | kapaa
# Processing Record 46 of Set 1 | karratha
# Processing Record 47 of Set 1 | clyde river
# Processing Record 48 of Set 1 | yellowknife
# Processing Record 49 of Set 1 | enderby
# Processing Record 50 of Set 1 | lavrentiya
# Processing Record 0 of Set 2 | atuona
# Processing Record 1 of Set 2 | faanui
# Processing Record 2 of Set 2 | rikitea
# Processing Record 3 of Set 2 | aklavik
# Processing Record 4 of Set 2 | sorland
# Processing Record 5 of Set 2 | zemio
# Processing Record 6 of Set 2 | changping
# Processing Record 7 of Set 2 | moroto
# Processing Record 8 of Set 2 | karaul
# City not found. Skipping...
# Processing Record 9 of Set 2 | dzhebariki-khaya
# Processing Record 10 of Set 2 | bandarbeyla
# Processing Record 11 of Set 2 | hualmay
# Processing Record 12 of Set 2 | busselton
# Processing Record 13 of Set 2 | poum
# Processing Record 14 of Set 2 | komsomolskiy
# Processing Record 15 of Set 2 | georgetown
# Processing Record 16 of Set 2 | thompson
# Processing Record 17 of Set 2 | pacifica
# Processing Record 18 of Set 2 | hithadhoo
# Processing Record 19 of Set 2 | manaus
# Processing Record 20 of Set 2 | acarau
# Processing Record 21 of Set 2 | port alfred
# Processing Record 22 of Set 2 | iaciara
# Processing Record 23 of Set 2 | kruisfontein
# Processing Record 24 of Set 2 | horki
# Processing Record 25 of Set 2 | castro
# Processing Record 26 of Set 2 | the valley
# Processing Record 27 of Set 2 | aksu
# Processing Record 28 of Set 2 | braives
# Processing Record 29 of Set 2 | vaini
# Processing Record 30 of Set 2 | richland
# Processing Record 31 of Set 2 | mahebourg
# Processing Record 32 of Set 2 | provideniya
# Processing Record 33 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 34 of Set 2 | makakilo city
# Processing Record 35 of Set 2 | bambous virieux
# Processing Record 36 of Set 2 | khani
# Processing Record 37 of Set 2 | bluff
# Processing Record 38 of Set 2 | bredasdorp
# Processing Record 39 of Set 2 | torbay
# Processing Record 40 of Set 2 | lata
# Processing Record 41 of Set 2 | half moon bay
# Processing Record 42 of Set 2 | ukrayinka
# Processing Record 43 of Set 2 | balkanabat
# Processing Record 44 of Set 2 | tsihombe
# City not found. Skipping...
# Processing Record 45 of Set 2 | cape town
# Processing Record 46 of Set 2 | pevek
# Processing Record 47 of Set 2 | bridlington
# Processing Record 48 of Set 2 | koumac
# Processing Record 49 of Set 2 | barrow
# Processing Record 0 of Set 3 | saskylakh
# Processing Record 1 of Set 3 | ambilobe
# Processing Record 2 of Set 3 | hamilton
# Processing Record 3 of Set 3 | saint-philippe
# Processing Record 4 of Set 3 | mingshui
# Processing Record 5 of Set 3 | nikolskoye
# Processing Record 6 of Set 3 | bonavista
# Processing Record 7 of Set 3 | mayo
# Processing Record 8 of Set 3 | hami
# Processing Record 9 of Set 3 | la asuncion
# Processing Record 10 of Set 3 | birao
# Processing Record 11 of Set 3 | punta arenas
# Processing Record 12 of Set 3 | jumla
# Processing Record 13 of Set 3 | bethel
# Processing Record 14 of Set 3 | grand river south east
# City not found. Skipping...
# Processing Record 15 of Set 3 | riviere-au-renard
# Processing Record 16 of Set 3 | yulara
# Processing Record 17 of Set 3 | santa isabel do rio negro
# Processing Record 18 of Set 3 | samana
# Processing Record 19 of Set 3 | mys shmidta
# City not found. Skipping...
# Processing Record 20 of Set 3 | isangel
# Processing Record 21 of Set 3 | kitimat
# Processing Record 22 of Set 3 | cankuzo
# Processing Record 23 of Set 3 | hilo
# Processing Record 24 of Set 3 | macaboboni
# City not found. Skipping...
# Processing Record 25 of Set 3 | vilaka
# Processing Record 26 of Set 3 | istok
# Processing Record 27 of Set 3 | san patricio
# Processing Record 28 of Set 3 | dunedin
# Processing Record 29 of Set 3 | sergeyevka
# Processing Record 30 of Set 3 | arraial do cabo
# Processing Record 31 of Set 3 | tiznit
# Processing Record 32 of Set 3 | nanortalik
# Processing Record 33 of Set 3 | sao joao da barra
# Processing Record 34 of Set 3 | biak
# Processing Record 35 of Set 3 | bandar-e anzali
# Processing Record 36 of Set 3 | boyabat
# Processing Record 37 of Set 3 | mar del plata
# Processing Record 38 of Set 3 | cururupu
# Processing Record 39 of Set 3 | sentyabrskiy
# City not found. Skipping...
# Processing Record 40 of Set 3 | clarence town
# Processing Record 41 of Set 3 | coihaique
# Processing Record 42 of Set 3 | tevaitoa
# Processing Record 43 of Set 3 | nishihara
# Processing Record 44 of Set 3 | ulaanbaatar
# Processing Record 45 of Set 3 | walvis bay
# Processing Record 46 of Set 3 | cidreira
# Processing Record 47 of Set 3 | salalah
# Processing Record 48 of Set 3 | norman wells
# Processing Record 49 of Set 3 | riyadh
# Processing Record 0 of Set 4 | peniche
# Processing Record 1 of Set 4 | sao luiz gonzaga
# Processing Record 2 of Set 4 | honningsvag
# Processing Record 3 of Set 4 | port elizabeth
# Processing Record 4 of Set 4 | saint-joseph
# Processing Record 5 of Set 4 | lagoa
# Processing Record 6 of Set 4 | zvishavane
# Processing Record 7 of Set 4 | airai
# Processing Record 8 of Set 4 | cabo san lucas
# Processing Record 9 of Set 4 | tuatapere
# Processing Record 10 of Set 4 | longlac
# City not found. Skipping...
# Processing Record 11 of Set 4 | tornio
# Processing Record 12 of Set 4 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 13 of Set 4 | kanniyakumari
# Processing Record 14 of Set 4 | padang
# Processing Record 15 of Set 4 | rawson
# Processing Record 16 of Set 4 | russkaya polyana
# Processing Record 17 of Set 4 | hay river
# Processing Record 18 of Set 4 | vila do maio
# Processing Record 19 of Set 4 | upernavik
# Processing Record 20 of Set 4 | tuktoyaktuk
# Processing Record 21 of Set 4 | nelson bay
# Processing Record 22 of Set 4 | tibagi
# Processing Record 23 of Set 4 | bima
# Processing Record 24 of Set 4 | leshukonskoye
# Processing Record 25 of Set 4 | borogontsy
# Processing Record 26 of Set 4 | nizhneyansk
# City not found. Skipping...
# Processing Record 27 of Set 4 | samusu
# City not found. Skipping...
# Processing Record 28 of Set 4 | luderitz
# Processing Record 29 of Set 4 | pangody
# Processing Record 30 of Set 4 | palembang
# Processing Record 31 of Set 4 | loandjili
# Processing Record 32 of Set 4 | qaanaaq
# Processing Record 33 of Set 4 | pitimbu
# Processing Record 34 of Set 4 | antofagasta
# Processing Record 35 of Set 4 | souillac
# Processing Record 36 of Set 4 | scottsbluff
# Processing Record 37 of Set 4 | yomitan
# City not found. Skipping...
# Processing Record 38 of Set 4 | srednekolymsk
# Processing Record 39 of Set 4 | pacific grove
# Processing Record 40 of Set 4 | labuhan
# Processing Record 41 of Set 4 | chokurdakh
# Processing Record 42 of Set 4 | lasem
# Processing Record 43 of Set 4 | groa
# Processing Record 44 of Set 4 | khatanga
# Processing Record 45 of Set 4 | raudeberg
# Processing Record 46 of Set 4 | antsohihy
# Processing Record 47 of Set 4 | the pas
# Processing Record 48 of Set 4 | dikson
# Processing Record 49 of Set 4 | udachnyy
# Processing Record 0 of Set 5 | valparaiso
# Processing Record 1 of Set 5 | kollam
# Processing Record 2 of Set 5 | vaitupu
# City not found. Skipping...
# Processing Record 3 of Set 5 | mount isa
# Processing Record 4 of Set 5 | teya
# Processing Record 5 of Set 5 | urdzhar
# City not found. Skipping...
# Processing Record 6 of Set 5 | berlevag
# Processing Record 7 of Set 5 | qasigiannguit
# Processing Record 8 of Set 5 | sultanpur
# Processing Record 9 of Set 5 | ilulissat
# Processing Record 10 of Set 5 | maceio
# Processing Record 11 of Set 5 | sangar
# Processing Record 12 of Set 5 | guerrero negro
# Processing Record 13 of Set 5 | deputatskiy
# Processing Record 14 of Set 5 | leningradskiy
# Processing Record 15 of Set 5 | carnarvon
# Processing Record 16 of Set 5 | vagamo
# Processing Record 17 of Set 5 | hua hin
# Processing Record 18 of Set 5 | lorengau
# Processing Record 19 of Set 5 | innisfail
# Processing Record 20 of Set 5 | tchibanga
# Processing Record 21 of Set 5 | avarua
# Processing Record 22 of Set 5 | pangai
# Processing Record 23 of Set 5 | nurobod
# Processing Record 24 of Set 5 | victoria
# Processing Record 25 of Set 5 | freeport
# Processing Record 26 of Set 5 | yirol
# City not found. Skipping...
# Processing Record 27 of Set 5 | hovd
# Processing Record 28 of Set 5 | malakal
# Processing Record 29 of Set 5 | joniskis
# Processing Record 30 of Set 5 | banjarmasin
# Processing Record 31 of Set 5 | rancho palos verdes
# Processing Record 32 of Set 5 | altay
# Processing Record 33 of Set 5 | arlit
# Processing Record 34 of Set 5 | gambela
# Processing Record 35 of Set 5 | bonito
# Processing Record 36 of Set 5 | qui nhon
# Processing Record 37 of Set 5 | belushya guba
# City not found. Skipping...
# Processing Record 38 of Set 5 | arona
# Processing Record 39 of Set 5 | ozu
# Processing Record 40 of Set 5 | goderich
# Processing Record 41 of Set 5 | kieta
# Processing Record 42 of Set 5 | kommunisticheskiy
# Processing Record 43 of Set 5 | sinnamary
# Processing Record 44 of Set 5 | northam
# Processing Record 45 of Set 5 | saint-pierre
# Processing Record 46 of Set 5 | juneau
# Processing Record 47 of Set 5 | nakhon phanom
# Processing Record 48 of Set 5 | east london
# Processing Record 49 of Set 5 | lima
# Processing Record 0 of Set 6 | buckeye
# Processing Record 1 of Set 6 | yabelo
# Processing Record 2 of Set 6 | katangli
# Processing Record 3 of Set 6 | lebu
# Processing Record 4 of Set 6 | puerto del rosario
# Processing Record 5 of Set 6 | viedma
# Processing Record 6 of Set 6 | teguldet
# Processing Record 7 of Set 6 | erice
# Processing Record 8 of Set 6 | baihar
# Processing Record 9 of Set 6 | tumannyy
# City not found. Skipping...
# Processing Record 10 of Set 6 | narsaq
# Processing Record 11 of Set 6 | skjervoy
# Processing Record 12 of Set 6 | zolotinka
# City not found. Skipping...
# Processing Record 13 of Set 6 | whyalla
# Processing Record 14 of Set 6 | silver city
# Processing Record 15 of Set 6 | jiddah
# City not found. Skipping...
# Processing Record 16 of Set 6 | gamba
# Processing Record 17 of Set 6 | erzin
# Processing Record 18 of Set 6 | tommot
# Processing Record 19 of Set 6 | nguiu
# City not found. Skipping...
# Processing Record 20 of Set 6 | saint anthony
# Processing Record 21 of Set 6 | paka
# Processing Record 22 of Set 6 | tautira
# Processing Record 23 of Set 6 | zurrieq
# Processing Record 24 of Set 6 | lashio
# Processing Record 25 of Set 6 | saldanha
# Processing Record 26 of Set 6 | oystese
# Processing Record 27 of Set 6 | tiksi
# Processing Record 28 of Set 6 | terra santa
# Processing Record 29 of Set 6 | darhan
# Processing Record 30 of Set 6 | aksehir
# Processing Record 31 of Set 6 | palabuhanratu
# City not found. Skipping...
# Processing Record 32 of Set 6 | sovetskiy
# Processing Record 33 of Set 6 | vao
# Processing Record 34 of Set 6 | grand-santi
# Processing Record 35 of Set 6 | anar darreh
# City not found. Skipping...
# Processing Record 36 of Set 6 | la ronge
# Processing Record 37 of Set 6 | muravlenko
# Processing Record 38 of Set 6 | ocos
# Processing Record 39 of Set 6 | alotau
# City not found. Skipping...
# Processing Record 40 of Set 6 | antalaha
# Processing Record 41 of Set 6 | hvide sande
# Processing Record 42 of Set 6 | kavaratti
# Processing Record 43 of Set 6 | dawei
# Processing Record 44 of Set 6 | imbituba
# Processing Record 45 of Set 6 | richards bay
# Processing Record 46 of Set 6 | toliary
# City not found. Skipping...
# Processing Record 47 of Set 6 | kalmunai
# Processing Record 48 of Set 6 | asau
# Processing Record 49 of Set 6 | grand centre
# City not found. Skipping...
# Processing Record 0 of Set 7 | oksfjord
# Processing Record 1 of Set 7 | lazaro cardenas
# Processing Record 2 of Set 7 | havre-saint-pierre
# Processing Record 3 of Set 7 | zhangye
# Processing Record 4 of Set 7 | sao filipe
# Processing Record 5 of Set 7 | kargil
# Processing Record 6 of Set 7 | alofi
# Processing Record 7 of Set 7 | verkh-tula
# Processing Record 8 of Set 7 | zeya
# Processing Record 9 of Set 7 | laguna
# Processing Record 10 of Set 7 | hambantota
# Processing Record 11 of Set 7 | attawapiskat
# City not found. Skipping...
# Processing Record 12 of Set 7 | codrington
# Processing Record 13 of Set 7 | waipawa
# Processing Record 14 of Set 7 | ayagoz
# Processing Record 15 of Set 7 | kailahun
# Processing Record 16 of Set 7 | praia da vitoria
# Processing Record 17 of Set 7 | mapimi
# Processing Record 18 of Set 7 | micheweni
# Processing Record 19 of Set 7 | lakes entrance
# Processing Record 20 of Set 7 | ossora
# Processing Record 21 of Set 7 | termoli
# Processing Record 22 of Set 7 | kroya
# Processing Record 23 of Set 7 | kaitangata
# Processing Record 24 of Set 7 | beringovskiy
# Processing Record 25 of Set 7 | port hedland
# Processing Record 26 of Set 7 | charters towers
# Processing Record 27 of Set 7 | yavaros
# Processing Record 28 of Set 7 | tilichiki
# Processing Record 29 of Set 7 | vila
# Processing Record 30 of Set 7 | boulder
# Processing Record 31 of Set 7 | mareeba
# Processing Record 32 of Set 7 | petropavlovsk-kamchatskiy
# Processing Record 33 of Set 7 | khanpur
# Processing Record 34 of Set 7 | orlik
# Processing Record 35 of Set 7 | ciudad bolivar
# Processing Record 36 of Set 7 | rio grande
# Processing Record 37 of Set 7 | stykkisholmur
# Processing Record 38 of Set 7 | pindi gheb
# Processing Record 39 of Set 7 | vaitape
# Processing Record 40 of Set 7 | aneho
# Processing Record 41 of Set 7 | saint-louis
# Processing Record 42 of Set 7 | hailun
# Processing Record 43 of Set 7 | yeniseysk
# Processing Record 44 of Set 7 | san javier
# Processing Record 45 of Set 7 | beian
# Processing Record 46 of Set 7 | ugoofaaru
# Processing Record 47 of Set 7 | cap malheureux
# Processing Record 48 of Set 7 | adrar
# Processing Record 49 of Set 7 | kavieng
# Processing Record 0 of Set 8 | haines junction
# Processing Record 1 of Set 8 | iqaluit
# Processing Record 2 of Set 8 | mayor pablo lagerenza
# Processing Record 3 of Set 8 | nusaybin
# Processing Record 4 of Set 8 | dzaoudzi
# Processing Record 5 of Set 8 | colquechaca
# Processing Record 6 of Set 8 | bambanglipuro
# Processing Record 7 of Set 8 | lompoc
# Processing Record 8 of Set 8 | namatanai
# Processing Record 9 of Set 8 | dauphin
# Processing Record 10 of Set 8 | ponta do sol
# Processing Record 11 of Set 8 | kasempa
# Processing Record 12 of Set 8 | tura
# Processing Record 13 of Set 8 | dwarka
# Processing Record 14 of Set 8 | ginir
# Processing Record 15 of Set 8 | bathsheba
# Processing Record 16 of Set 8 | batagay-alyta
# Processing Record 17 of Set 8 | bastia
# Processing Record 18 of Set 8 | vallenar
# Processing Record 19 of Set 8 | novikovo
# Processing Record 20 of Set 8 | constitucion
# Processing Record 21 of Set 8 | limerick
# Processing Record 22 of Set 8 | partenit
# Processing Record 23 of Set 8 | odweyne
# Processing Record 24 of Set 8 | hasaki
# Processing Record 25 of Set 8 | paamiut
# Processing Record 26 of Set 8 | chapayevka
# Processing Record 27 of Set 8 | uusikaupunki
# Processing Record 28 of Set 8 | saleaula
# City not found. Skipping...
# Processing Record 29 of Set 8 | dingle
# Processing Record 30 of Set 8 | vardo
# Processing Record 31 of Set 8 | saint-gilles
# Processing Record 32 of Set 8 | abapo
# Processing Record 33 of Set 8 | tuggurt
# City not found. Skipping...
# Processing Record 34 of Set 8 | ayan
# Processing Record 35 of Set 8 | follonica
# Processing Record 36 of Set 8 | shwebo
# Processing Record 37 of Set 8 | kainantu
# Processing Record 38 of Set 8 | chimbote
# Processing Record 39 of Set 8 | port blair
# Processing Record 40 of Set 8 | severo-yeniseyskiy
# Processing Record 41 of Set 8 | kamenskoye
# City not found. Skipping...
# Processing Record 42 of Set 8 | talnakh
# Processing Record 43 of Set 8 | tonj
# Processing Record 44 of Set 8 | port-de-bouc
# Processing Record 45 of Set 8 | lyman
# Processing Record 46 of Set 8 | bereznik
# Processing Record 47 of Set 8 | bilma
# Processing Record 48 of Set 8 | ifakara
# Processing Record 49 of Set 8 | fortuna
# Processing Record 0 of Set 9 | karatau
# Processing Record 1 of Set 9 | cayenne
# Processing Record 2 of Set 9 | boatlaname
# City not found. Skipping...
# Processing Record 3 of Set 9 | oranjemund
# Processing Record 4 of Set 9 | blairmore
# Processing Record 5 of Set 9 | majene
# Processing Record 6 of Set 9 | omsukchan
# Processing Record 7 of Set 9 | naron
# Processing Record 8 of Set 9 | zhanaozen
# Processing Record 9 of Set 9 | gayny
# Processing Record 10 of Set 9 | bulnes
# Processing Record 11 of Set 9 | cacoal
# Processing Record 12 of Set 9 | preeceville
# Processing Record 13 of Set 9 | umm kaddadah
# Processing Record 14 of Set 9 | aflu
# City not found. Skipping...
# Processing Record 15 of Set 9 | cherskiy
# Processing Record 16 of Set 9 | marcona
# City not found. Skipping...
# Processing Record 17 of Set 9 | saint-francois
# Processing Record 18 of Set 9 | acapulco
# Processing Record 19 of Set 9 | registro
# Processing Record 20 of Set 9 | kahului
# Processing Record 21 of Set 9 | llangefni
# Processing Record 22 of Set 9 | meyungs
# City not found. Skipping...
# Processing Record 23 of Set 9 | seoul
# Processing Record 24 of Set 9 | midland
# Processing Record 25 of Set 9 | pampa
# Processing Record 26 of Set 9 | barawe
# City not found. Skipping...
# Processing Record 27 of Set 9 | moron
# Processing Record 28 of Set 9 | maun
# Processing Record 29 of Set 9 | contepec
# Processing Record 30 of Set 9 | tuskegee
# Processing Record 31 of Set 9 | batticaloa
# Processing Record 32 of Set 9 | klaksvik
# Processing Record 33 of Set 9 | porto santo
# Processing Record 34 of Set 9 | jacksonville
# Processing Record 35 of Set 9 | namibe
# Processing Record 36 of Set 9 | san ignacio
# Processing Record 37 of Set 9 | wembley
# Processing Record 38 of Set 9 | muros
# Processing Record 39 of Set 9 | coueron
# Processing Record 40 of Set 9 | batsfjord
# Processing Record 41 of Set 9 | yatou
# Processing Record 42 of Set 9 | kirakira
# Processing Record 43 of Set 9 | new philadelphia
# Processing Record 44 of Set 9 | tlacotalpan
# Processing Record 45 of Set 9 | beloha
# Processing Record 46 of Set 9 | tra vinh
# Processing Record 47 of Set 9 | palafrugell
# Processing Record 48 of Set 9 | zlitan
# Processing Record 49 of Set 9 | green river
# Processing Record 0 of Set 10 | maragheh
# Processing Record 1 of Set 10 | elizabeth city
# Processing Record 2 of Set 10 | agadez
# Processing Record 3 of Set 10 | mana
# Processing Record 4 of Set 10 | corn island
# Processing Record 5 of Set 10 | alappuzha
# Processing Record 6 of Set 10 | leh
# Processing Record 7 of Set 10 | atar
# Processing Record 8 of Set 10 | griffith
# Processing Record 9 of Set 10 | mehndawal
# Processing Record 10 of Set 10 | bossangoa
# Processing Record 11 of Set 10 | eureka
# Processing Record 12 of Set 10 | grand-lahou
# Processing Record 13 of Set 10 | inhambane
# Processing Record 14 of Set 10 | fort nelson
# Processing Record 15 of Set 10 | lander
# Processing Record 16 of Set 10 | aripuana
# Processing Record 17 of Set 10 | araouane
# Processing Record 18 of Set 10 | boyolangu
# Processing Record 19 of Set 10 | alta floresta
# Processing Record 20 of Set 10 | lamphun
# Processing Record 21 of Set 10 | kristiansund
# Processing Record 22 of Set 10 | kasungu
# Processing Record 23 of Set 10 | castanos
# Processing Record 24 of Set 10 | mezhdurechensk
# Processing Record 25 of Set 10 | luvianos
# Processing Record 26 of Set 10 | patiya
# Processing Record 27 of Set 10 | taoudenni
# Processing Record 28 of Set 10 | nome
# Processing Record 29 of Set 10 | maniitsoq
# Processing Record 30 of Set 10 | waddan
# Processing Record 31 of Set 10 | minab
# Processing Record 32 of Set 10 | rokytne
# Processing Record 33 of Set 10 | abu samrah
# Processing Record 34 of Set 10 | phalodi
# Processing Record 35 of Set 10 | longyearbyen
# Processing Record 36 of Set 10 | huron
# Processing Record 37 of Set 10 | ahipara
# Processing Record 38 of Set 10 | xianyang
# Processing Record 39 of Set 10 | basco
# Processing Record 40 of Set 10 | moindou
# Processing Record 41 of Set 10 | krasnoye
# Processing Record 42 of Set 10 | idanre
# Processing Record 43 of Set 10 | greeneville
# Processing Record 44 of Set 10 | la reforma
# Processing Record 45 of Set 10 | severo-kurilsk
# Processing Record 46 of Set 10 | coquimbo
# Processing Record 47 of Set 10 | college
# Processing Record 48 of Set 10 | port-de-paix
# City not found. Skipping...
# Processing Record 49 of Set 10 | taoru
# Processing Record 0 of Set 11 | garowe
# Processing Record 1 of Set 11 | reefton
# City not found. Skipping...
# Processing Record 2 of Set 11 | conde
# Processing Record 3 of Set 11 | touros
# Processing Record 4 of Set 11 | honiara
# Processing Record 5 of Set 11 | otane
# Processing Record 6 of Set 11 | port hardy
# Processing Record 7 of Set 11 | soyo
# Processing Record 8 of Set 11 | lodja
# Processing Record 9 of Set 11 | tambul
# City not found. Skipping...
# Processing Record 10 of Set 11 | tongliao
# Processing Record 11 of Set 11 | fort saint john
# City not found. Skipping...
# Processing Record 12 of Set 11 | samalaeulu
# City not found. Skipping...
# Processing Record 13 of Set 11 | praia
# Processing Record 14 of Set 11 | poronaysk
# Processing Record 15 of Set 11 | petauke
# Processing Record 16 of Set 11 | itarema
# Processing Record 17 of Set 11 | obzor
# Processing Record 18 of Set 11 | mount gambier
# Processing Record 19 of Set 11 | omis
# Processing Record 20 of Set 11 | campos
# Processing Record 21 of Set 11 | yar-sale
# Processing Record 22 of Set 11 | asyut
# Processing Record 23 of Set 11 | poplar bluff
# Processing Record 24 of Set 11 | daru
# Processing Record 25 of Set 11 | bud
# Processing Record 26 of Set 11 | kibakwe
# Processing Record 27 of Set 11 | talladega
# Processing Record 28 of Set 11 | skjaerhollen
# City not found. Skipping...
# Processing Record 29 of Set 11 | goure
# Processing Record 30 of Set 11 | tual
# Processing Record 31 of Set 11 | vestmanna
# Processing Record 32 of Set 11 | wewak
# Processing Record 33 of Set 11 | road town
# Processing Record 34 of Set 11 | tendukheda
# Processing Record 35 of Set 11 | novyy rogachik
# Processing Record 36 of Set 11 | san cristobal
# Processing Record 37 of Set 11 | savannah bight
# Processing Record 38 of Set 11 | bytow
# Processing Record 39 of Set 11 | harper
# Processing Record 40 of Set 11 | taunggyi
# Processing Record 41 of Set 11 | kilindoni
# Processing Record 42 of Set 11 | gisborne
# Processing Record 43 of Set 11 | gao
# Processing Record 44 of Set 11 | moerai
# Processing Record 45 of Set 11 | tabou
# Processing Record 46 of Set 11 | xinzhou
# Processing Record 47 of Set 11 | xixiang
# Processing Record 48 of Set 11 | lisakovsk
# Processing Record 49 of Set 11 | show low
# Processing Record 0 of Set 12 | aswan
# Processing Record 1 of Set 12 | baykit
# Processing Record 2 of Set 12 | muzquiz
# City not found. Skipping...
# Processing Record 3 of Set 12 | zhigansk
# Processing Record 4 of Set 12 | mogok
# Processing Record 5 of Set 12 | warqla
# City not found. Skipping...
# Processing Record 6 of Set 12 | sidi qasim
# City not found. Skipping...
# Processing Record 7 of Set 12 | vila franca do campo
# Processing Record 8 of Set 12 | nebbi
# Processing Record 9 of Set 12 | westport
# Processing Record 10 of Set 12 | edmonton
# Processing Record 11 of Set 12 | cockburn town
# Processing Record 12 of Set 12 | pisco
# Processing Record 13 of Set 12 | kempsey
# Processing Record 14 of Set 12 | khandyga
# Processing Record 15 of Set 12 | shelburne
# Processing Record 16 of Set 12 | campbellsville
# Processing Record 17 of Set 12 | sorong
# Processing Record 18 of Set 12 | asosa
# Processing Record 19 of Set 12 | kegayli
# City not found. Skipping...
# Processing Record 20 of Set 12 | coulihaut
# City not found. Skipping...
# Processing Record 21 of Set 12 | bergisch gladbach
# Processing Record 22 of Set 12 | guano
# Processing Record 23 of Set 12 | sterling
# Processing Record 24 of Set 12 | bay roberts
# Processing Record 25 of Set 12 | bereda
# Processing Record 26 of Set 12 | uvira
# Processing Record 27 of Set 12 | bocaiuva
# Processing Record 28 of Set 12 | ixtapa
# Processing Record 29 of Set 12 | glace bay
# Processing Record 30 of Set 12 | yumen
# Processing Record 31 of Set 12 | katha
# City not found. Skipping...
# Processing Record 32 of Set 12 | caravelas
# Processing Record 33 of Set 12 | tashla
# Processing Record 34 of Set 12 | beisfjord
# Processing Record 35 of Set 12 | pochutla
# Processing Record 36 of Set 12 | teseney
# Processing Record 37 of Set 12 | sakakah
# Processing Record 38 of Set 12 | grants pass
# Processing Record 39 of Set 12 | sao miguel do araguaia
# Processing Record 40 of Set 12 | vanderhoof
# Processing Record 41 of Set 12 | nuuk
# Processing Record 42 of Set 12 | waitati
# Processing Record 43 of Set 12 | tucuma
# Processing Record 44 of Set 12 | sisimiut
# Processing Record 45 of Set 12 | roebourne
# Processing Record 46 of Set 12 | camacha
# Processing Record 47 of Set 12 | byron bay
# Processing Record 48 of Set 12 | rockland
# Processing Record 49 of Set 12 | olafsvik
# Processing Record 0 of Set 13 | qidong
# Processing Record 1 of Set 13 | lasa
# Processing Record 2 of Set 13 | comodoro rivadavia
# Processing Record 3 of Set 13 | mountain home
# Processing Record 4 of Set 13 | togur
# Processing Record 5 of Set 13 | lushunkou
# City not found. Skipping...
# Processing Record 6 of Set 13 | whitehorse
# Processing Record 7 of Set 13 | kashi
# Processing Record 8 of Set 13 | marawi
# Processing Record 9 of Set 13 | san jose
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)

# Show Record Count
city_data_df.count()
# Out:
# City          559
# Lat           559
# Lng           559
# Max Temp      559
# Humidity      559
# Cloudiness    559
# Wind Speed    559
# Country       559
# Date          559
# dtype: int64

# %%
# Display sample data
city_data_df.head()
# Out:
#              City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0          itoman  26.1247  127.6694     16.01        67          40
# 1  fereydun kenar  36.6864   52.5225      7.63        69           7
# 2        bengkulu  -3.8004  102.2655     23.39        90         100
# 3          albany  42.6001  -73.9662     16.23        50           6
# 4        katsuura  35.1333  140.3000      3.08        59          37
#
#    Wind Speed Country        Date
# 0        5.14      JP  1676499981
# 1        0.64      IR  1676499982
# 2        1.92      ID  1676499949
# 3        0.45      US  1676499984
# 4        6.27      JP  1676499985

# %%
# Export the City_Data into a csv
city_data_df.to_csv("cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
#                    City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0                itoman  26.1247  127.6694     16.01        67          40
# 1        fereydun kenar  36.6864   52.5225      7.63        69           7
# 2              bengkulu  -3.8004  102.2655     23.39        90         100
# 3                albany  42.6001  -73.9662     16.23        50           6
# 4              katsuura  35.1333  140.3000      3.08        59          37
#
#          Wind Speed Country        Date
# City_ID
# 0              5.14      JP  1676499981
# 1              0.64      IR  1676499982
# 2              1.92      ID  1676499949
# 3              0.45      US  1676499984
# 4              6.27      JP  1676499985

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature
plt.scatter(city_data_df["Lat"], city_data_df["Max Temp"], marker="o", edgecolors="black")

# Incorporate the other graph properties
plt.title("City Max Latitude vs. Temperature (2023-01-22)")
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (C)")
plt.grid(True)

# Save the figure
plt.savefig("Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity
plt.scatter(city_data_df["Lat"], city_data_df["Humidity"], marker="o", edgecolors="black")

# Incorporate the other graph properties
plt.title("City Latitude vs. Humidity (2023-01-22)")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.grid(True)

# Save the figure
plt.savefig("Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
plt.scatter(city_data_df["Lat"], city_data_df["Cloudiness"], marker="o", edgecolors="black")

# Incorporate the other graph properties
plt.title("City Latitude vs. Cloudiness (2023-01-22)")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.grid(True)

# Save the figure
plt.savefig("Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
plt.scatter(city_data_df["Lat"], city_data_df["Wind Speed"], marker="o", edgecolors="black")

# Incorporate the other graph properties
plt.title("City Latitude vs. Wind Speed (2023-01-22)")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (m/s)")
plt.grid(True)

# Save the figure
plt.savefig("Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Define a function to create Linear Regression plots
def linear_regression_plots(x_values, y_values):
    (slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
    regression_values = x_values * slope + intercept
    line_eq = "y = " + str(round(slope, 2)) + "x +" + str(round(intercept, 2))
    
    plt.scatter(x_values, y_values, marker="o")
    plt.plot(x_values, regression_values, "r-")
    
    
    print(f"The r-value is : {rvalue ** 2}")
    return line_eq

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
northern_hemi_df = city_data_df[city_data_df["Lat"] >= 0]

# Display sample data
northern_hemi_df.head()
# Out:
#                    City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0                itoman  26.1247  127.6694     16.01        67          40
# 1        fereydun kenar  36.6864   52.5225      7.63        69           7
# 3                albany  42.6001  -73.9662     16.23        50           6
# 4              katsuura  35.1333  140.3000      3.08        59          37
# 8             fairbanks  64.8378 -147.7164    -13.21        74          75
#
#          Wind Speed Country        Date
# City_ID
# 0              5.14      JP  1676499981
# 1              0.64      IR  1676499982
# 3              0.45      US  1676499984
# 4              6.27      JP  1676499985
# 8              1.54      US  1676499987

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
southern_hemi_df = city_data_df[city_data_df["Lat"] < 0]

# Display sample data
southern_hemi_df
# Out:
#                        City      Lat       Lng  Max Temp  Humidity  \
# City_ID
# 2                  bengkulu  -3.8004  102.2655     23.39        90
# 5                  ilhabela -23.7781  -45.3581     26.96        83
# 6                    hobart -42.8794  147.3294     19.59        75
# 7                  flinders -34.5833  150.8552     23.47        76
# 9                 springbok -29.6643   17.8865     14.54        85
# ...                     ...      ...       ...       ...       ...
# 542                 waitati -45.7500  170.5667     14.89        74
# 543                  tucuma  -0.1833  -50.0500     24.55        94
# 545               roebourne -20.7833  117.1333     32.53        30
# 547               byron bay -28.6500  153.6167     22.75        60
# 552      comodoro rivadavia -45.8667  -67.5000     14.92        21
#
#          Cloudiness  Wind Speed Country        Date
# City_ID
# 2               100        1.92      ID  1676499949
# 5                96        1.84      BR  1676499986
# 6                75        4.12      AU  1676499815
# 7                45        2.68      AU  1676499987
# 9                 0        1.79      ZA  1676499531
# ...             ...         ...     ...         ...
# 542              90        3.58      NZ  1676500344
# 543             100        2.74      BR  1676500132
# 545              14        2.08      AU  1676500346
# 547              22        3.02      AU  1676500348
# 552              40        8.23      AR  1676500351
#
# [176 rows x 9 columns]

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere
regress_temp_northern_hemi = linear_regression_plots(northern_hemi_df["Lat"], northern_hemi_df["Max Temp"])
regress_temp_northern_hemi

plt.xlabel("Latitude")
plt.ylabel("Max Temp")
plt.annotate(regress_temp_northern_hemi, (5, -30), fontsize=15, color="red")
plt.show()
# Out:
# The r-value is : 0.6578552120291798

# %%
# Linear regression on Southern Hemisphere
regress_temp_southern_hemi = linear_regression_plots(southern_hemi_df["Lat"], southern_hemi_df["Max Temp"])
regress_temp_southern_hemi

plt.xlabel("Latitude")
plt.ylabel("Max Temp")
plt.annotate(regress_temp_southern_hemi, (-55, 30), fontsize=15, color="red")
plt.show()
# Out:
# The r-value is : 0.2368660487965422

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
regression_humidity_northern_hemi = linear_regression_plots(northern_hemi_df["Lat"], northern_hemi_df["Humidity"])
regression_humidity_northern_hemi

plt.xlabel("Latitude")
plt.ylabel("Humidity")
plt.annotate(regression_humidity_northern_hemi, (45, 15), fontsize=15, color="red")
plt.show()
# Out:
# The r-value is : 0.2013797221351963

# %%
# Southern Hemisphere
regression_humidity_southern_hemi = linear_regression_plots(southern_hemi_df["Lat"], southern_hemi_df["Humidity"])
regression_humidity_southern_hemi

plt.xlabel("Latitude")
plt.ylabel("Humidity")
plt.annotate(regression_humidity_southern_hemi, (-50, 25), fontsize=15, color="red")
plt.show()
# Out:
# The r-value is : 0.19732798013883845

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
regression_cloud_northern_hemi = linear_regression_plots(northern_hemi_df["Lat"], northern_hemi_df["Cloudiness"])
regression_cloud_northern_hemi

plt.xlabel("Latitude")
plt.ylabel("Cloudiness")
plt.annotate(regression_cloud_northern_hemi, (45, 15), fontsize=15, color="red")
plt.show()
# Out:
# The r-value is : 0.13384664808905064

# %%
# Southern Hemisphere
regression_cloud_southern_hemi = linear_regression_plots(southern_hemi_df["Lat"], southern_hemi_df["Cloudiness"])
regression_cloud_southern_hemi

plt.xlabel("Latitude")
plt.ylabel("Cloudiness")
plt.annotate(regression_cloud_southern_hemi, (-50, 25), fontsize=15, color="red")
plt.show()
# Out:
# The r-value is : 0.0474856134217314

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
regression_wind_northern_hemi = linear_regression_plots(northern_hemi_df["Lat"], northern_hemi_df["Wind Speed"])
regression_wind_northern_hemi

plt.xlabel("Latitude")
plt.ylabel("Wind Speed")
plt.annotate(regression_wind_northern_hemi, (45, 15), fontsize=15, color="red")
plt.show()
# Out:
# The r-value is : 2.766417840151644e-08

# %%
# Southern Hemisphere
regression_wind_southern_hemi = linear_regression_plots(southern_hemi_df["Lat"], southern_hemi_df["Wind Speed"])
regression_wind_southern_hemi

plt.xlabel("Latitude")
plt.ylabel("Wind Speed")
plt.annotate(regression_wind_southern_hemi, (-50, 10), fontsize=15, color="red")
plt.show()
# Out:
# The r-value is : 0.15347800671551826

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %%
import sys
# !{sys.executable} -m pip install scipy citipy pandas matplotlib
# Out:
# Requirement already satisfied: scipy in c:\users\sriha\anaconda3\lib\site-packages (1.9.1)
# Requirement already satisfied: citipy in c:\users\sriha\anaconda3\lib\site-packages (0.0.5)
# Requirement already satisfied: pandas in c:\users\sriha\anaconda3\lib\site-packages (1.4.4)
# Requirement already satisfied: matplotlib in c:\users\sriha\anaconda3\lib\site-packages (3.5.2)
# Requirement already satisfied: numpy<1.25.0,>=1.18.5 in c:\users\sriha\anaconda3\lib\site-packages (from scipy) (1.21.5)
# Requirement already satisfied: kdtree>=0.12 in c:\users\sriha\anaconda3\lib\site-packages (from citipy) (0.16)
# Requirement already satisfied: pytz>=2020.1 in c:\users\sriha\anaconda3\lib\site-packages (from pandas) (2022.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\sriha\anaconda3\lib\site-packages (from pandas) (2.8.2)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\sriha\anaconda3\lib\site-packages (from matplotlib) (4.25.0)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\sriha\anaconda3\lib\site-packages (from matplotlib) (9.2.0)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\sriha\anaconda3\lib\site-packages (from matplotlib) (3.0.9)
# Requirement already satisfied: packaging>=20.0 in c:\users\sriha\anaconda3\lib\site-packages (from matplotlib) (21.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\sriha\anaconda3\lib\site-packages (from matplotlib) (1.4.2)
# Requirement already satisfied: cycler>=0.10 in c:\users\sriha\anaconda3\lib\site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: six>=1.5 in c:\users\sriha\anaconda3\lib\site-packages (from python-dateutil>=2.8.1->pandas) (1.16.0)
